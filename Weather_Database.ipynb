# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 734

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jutai
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | marand
# Processing Record 10 of Set 1 | las vegas
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | kristiansund
# Processing Record 15 of Set 1 | olivehurst
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | westport
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | zarand
# Processing Record 22 of Set 1 | san ramon
# Processing Record 23 of Set 1 | san cristobal
# Processing Record 24 of Set 1 | alma
# Processing Record 25 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | panjab
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | boddam
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | hami
# Processing Record 32 of Set 1 | presidencia roque saenz pena
# Processing Record 33 of Set 1 | pitimbu
# Processing Record 34 of Set 1 | malindi
# Processing Record 35 of Set 1 | zhigansk
# Processing Record 36 of Set 1 | gafargaon
# Processing Record 37 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | davidson
# Processing Record 41 of Set 1 | roald
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | santa rosa
# Processing Record 46 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 1 | hamilton
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | christchurch
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | san carlos de bariloche
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 2 | sambava
# Processing Record 11 of Set 2 | prince rupert
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | mormugao
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | yatou
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | kalachinsk
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | quesnel
# Processing Record 23 of Set 2 | rudbar
# Processing Record 24 of Set 2 | grand gaube
# Processing Record 25 of Set 2 | da nang
# Processing Record 26 of Set 2 | chifeng
# Processing Record 27 of Set 2 | kaabong
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | turukhansk
# Processing Record 30 of Set 2 | bubaque
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | safaga
# Processing Record 35 of Set 2 | kangaatsiaq
# Processing Record 36 of Set 2 | smithers
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | himora
# City not found. Skipping...
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | sovetskiy
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | emerald
# Processing Record 45 of Set 2 | roma
# Processing Record 46 of Set 2 | shimoda
# Processing Record 47 of Set 2 | loandjili
# Processing Record 48 of Set 2 | ajaccio
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | lavrentiya
# Processing Record 2 of Set 3 | formosa
# Processing Record 3 of Set 3 | piterka
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | pudozh
# Processing Record 6 of Set 3 | muzhi
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | denpasar
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | tilichiki
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | port hedland
# Processing Record 14 of Set 3 | itinga
# Processing Record 15 of Set 3 | urucuca
# Processing Record 16 of Set 3 | manokwari
# Processing Record 17 of Set 3 | sola
# Processing Record 18 of Set 3 | astana
# Processing Record 19 of Set 3 | carutapera
# Processing Record 20 of Set 3 | amli
# Processing Record 21 of Set 3 | kudahuvadhoo
# Processing Record 22 of Set 3 | riyadh
# Processing Record 23 of Set 3 | dutse
# Processing Record 24 of Set 3 | samarai
# Processing Record 25 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | birao
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | baykit
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | maniitsoq
# Processing Record 34 of Set 3 | kuytun
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | bilibino
# Processing Record 38 of Set 3 | kenai
# Processing Record 39 of Set 3 | mekhe
# Processing Record 40 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 3 | pouebo
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | assiniboia
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | calvinia
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | bilma
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | burgersdorp
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | the valley
# Processing Record 5 of Set 4 | mildura
# Processing Record 6 of Set 4 | veraval
# Processing Record 7 of Set 4 | piacabucu
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | neiafu
# Processing Record 10 of Set 4 | solvychegodsk
# Processing Record 11 of Set 4 | sioux lookout
# Processing Record 12 of Set 4 | kampot
# Processing Record 13 of Set 4 | khani
# Processing Record 14 of Set 4 | nuevo imperial
# Processing Record 15 of Set 4 | micheweni
# Processing Record 16 of Set 4 | bridlington
# Processing Record 17 of Set 4 | sibolga
# Processing Record 18 of Set 4 | wanaka
# Processing Record 19 of Set 4 | maningrida
# Processing Record 20 of Set 4 | vila
# Processing Record 21 of Set 4 | pochutla
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | salamanca
# Processing Record 24 of Set 4 | coquimbo
# Processing Record 25 of Set 4 | palmer
# Processing Record 26 of Set 4 | ozinki
# Processing Record 27 of Set 4 | buraydah
# Processing Record 28 of Set 4 | caravelas
# Processing Record 29 of Set 4 | agadir
# Processing Record 30 of Set 4 | leningradskiy
# Processing Record 31 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 4 | evensk
# Processing Record 33 of Set 4 | elliot lake
# Processing Record 34 of Set 4 | yonibana
# Processing Record 35 of Set 4 | imeni poliny osipenko
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | senneterre
# Processing Record 39 of Set 4 | puerto ayora
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | bairiki
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | oranjemund
# Processing Record 46 of Set 4 | puerto lempira
# Processing Record 47 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 4 | pecos
# Processing Record 49 of Set 4 | dunedin
# Processing Record 50 of Set 4 | puerto escondido
# Processing Record 1 of Set 5 | boende
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | sale
# Processing Record 4 of Set 5 | bingol
# Processing Record 5 of Set 5 | ambilobe
# Processing Record 6 of Set 5 | tikrit
# Processing Record 7 of Set 5 | morro bay
# Processing Record 8 of Set 5 | monrovia
# Processing Record 9 of Set 5 | tucurui
# Processing Record 10 of Set 5 | ndele
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | fukue
# Processing Record 13 of Set 5 | el vigia
# Processing Record 14 of Set 5 | srimushnam
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | markdale
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | dakar
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | banda aceh
# Processing Record 24 of Set 5 | miramar
# Processing Record 25 of Set 5 | ayr
# Processing Record 26 of Set 5 | bitola
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | krasnyy chikoy
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | tautira
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | cururupu
# Processing Record 35 of Set 5 | tasiilaq
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | plainview
# Processing Record 38 of Set 5 | aljezur
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | carnarvon
# Processing Record 41 of Set 5 | mafinga
# Processing Record 42 of Set 5 | inta
# Processing Record 43 of Set 5 | salalah
# Processing Record 44 of Set 5 | kasongo-lunda
# Processing Record 45 of Set 5 | college
# Processing Record 46 of Set 5 | miles city
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | den helder
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | tuatapere
# Processing Record 1 of Set 6 | brigantine
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 4 of Set 6 | kapuskasing
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | mapiripan
# Processing Record 7 of Set 6 | hofn
# Processing Record 8 of Set 6 | klyuchi
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | rennes
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | bud
# Processing Record 16 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 6 | tainan
# Processing Record 18 of Set 6 | ceres
# Processing Record 19 of Set 6 | lokosovo
# Processing Record 20 of Set 6 | esperance
# Processing Record 21 of Set 6 | ranir bazar
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | namatanai
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | freetown
# Processing Record 26 of Set 6 | kathu
# Processing Record 27 of Set 6 | fort nelson
# Processing Record 28 of Set 6 | vanimo
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | sobradinho
# Processing Record 31 of Set 6 | moyale
# Processing Record 32 of Set 6 | biryusinsk
# Processing Record 33 of Set 6 | batagay
# Processing Record 34 of Set 6 | san vicente
# Processing Record 35 of Set 6 | wynyard
# Processing Record 36 of Set 6 | dosso
# Processing Record 37 of Set 6 | talaya
# Processing Record 38 of Set 6 | suna
# Processing Record 39 of Set 6 | baculin
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | santa fe
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | tuy hoa
# Processing Record 44 of Set 6 | bhandara
# Processing Record 45 of Set 6 | ugoofaaru
# Processing Record 46 of Set 6 | chicama
# Processing Record 47 of Set 6 | fernandopolis
# Processing Record 48 of Set 6 | tulun
# Processing Record 49 of Set 6 | tiksi
# Processing Record 50 of Set 6 | pachino
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | rosarito
# Processing Record 3 of Set 7 | bambanglipuro
# Processing Record 4 of Set 7 | pandan
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | santa isabel do rio negro
# Processing Record 8 of Set 7 | constitucion
# Processing Record 9 of Set 7 | arman
# Processing Record 10 of Set 7 | hengyang
# Processing Record 11 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 12 of Set 7 | ridgecrest
# Processing Record 13 of Set 7 | el fuerte
# Processing Record 14 of Set 7 | nedjo
# Processing Record 15 of Set 7 | nara
# Processing Record 16 of Set 7 | warangal
# Processing Record 17 of Set 7 | yorkton
# Processing Record 18 of Set 7 | souillac
# Processing Record 19 of Set 7 | pokanayevka
# City not found. Skipping...
# Processing Record 20 of Set 7 | taloqan
# Processing Record 21 of Set 7 | rubtsovsk
# Processing Record 22 of Set 7 | bam
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | rawson
# Processing Record 25 of Set 7 | paita
# Processing Record 26 of Set 7 | kiruna
# Processing Record 27 of Set 7 | shubarkuduk
# Processing Record 28 of Set 7 | turayf
# Processing Record 29 of Set 7 | trinidad
# Processing Record 30 of Set 7 | bac lieu
# Processing Record 31 of Set 7 | vangaindrano
# Processing Record 32 of Set 7 | la crosse
# Processing Record 33 of Set 7 | waterloo
# Processing Record 34 of Set 7 | opelousas
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | mae ramat
# Processing Record 38 of Set 7 | great bend
# Processing Record 39 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 40 of Set 7 | muros
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | constantine
# Processing Record 43 of Set 7 | rafraf
# Processing Record 44 of Set 7 | north bend
# Processing Record 45 of Set 7 | berlevag
# Processing Record 46 of Set 7 | havre-saint-pierre
# Processing Record 47 of Set 7 | kondoa
# Processing Record 48 of Set 7 | new baltimore
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | trebisacce
# Processing Record 1 of Set 8 | beckley
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | awjilah
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | karakol
# Processing Record 6 of Set 8 | ust-tsilma
# Processing Record 7 of Set 8 | pisco
# Processing Record 8 of Set 8 | ust-maya
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | mandalgovi
# Processing Record 11 of Set 8 | paamiut
# Processing Record 12 of Set 8 | orasac
# Processing Record 13 of Set 8 | buluang
# Processing Record 14 of Set 8 | champaign
# Processing Record 15 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | matagami
# Processing Record 18 of Set 8 | shawville
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | aguimes
# Processing Record 21 of Set 8 | lagoa
# Processing Record 22 of Set 8 | itoman
# Processing Record 23 of Set 8 | clyde river
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | nangan
# Processing Record 26 of Set 8 | kansanshi
# Processing Record 27 of Set 8 | nuuk
# Processing Record 28 of Set 8 | sug-aksy
# City not found. Skipping...
# Processing Record 29 of Set 8 | buala
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | shache
# Processing Record 32 of Set 8 | hanyang
# Processing Record 33 of Set 8 | mangrol
# Processing Record 34 of Set 8 | hualmay
# Processing Record 35 of Set 8 | hadejia
# Processing Record 36 of Set 8 | samalkha
# Processing Record 37 of Set 8 | muscat
# Processing Record 38 of Set 8 | syracuse
# Processing Record 39 of Set 8 | orsha
# Processing Record 40 of Set 8 | grindavik
# Processing Record 41 of Set 8 | moron
# Processing Record 42 of Set 8 | turan
# Processing Record 43 of Set 8 | san quintin
# Processing Record 44 of Set 8 | pevek
# Processing Record 45 of Set 8 | bury saint edmunds
# City not found. Skipping...
# Processing Record 46 of Set 8 | tokur
# Processing Record 47 of Set 8 | pontian kecil
# Processing Record 48 of Set 8 | sao borja
# Processing Record 49 of Set 8 | kulykiv
# Processing Record 50 of Set 8 | gurupa
# Processing Record 1 of Set 9 | sao filipe
# Processing Record 2 of Set 9 | makakilo city
# Processing Record 3 of Set 9 | chumikan
# Processing Record 4 of Set 9 | lithgow
# Processing Record 5 of Set 9 | port elizabeth
# Processing Record 6 of Set 9 | berdigestyakh
# Processing Record 7 of Set 9 | wasilla
# Processing Record 8 of Set 9 | faanui
# Processing Record 9 of Set 9 | sulurpeta
# City not found. Skipping...
# Processing Record 10 of Set 9 | sassandra
# Processing Record 11 of Set 9 | zalantun
# Processing Record 12 of Set 9 | shubarshi
# Processing Record 13 of Set 9 | awbari
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | bereda
# Processing Record 16 of Set 9 | gaozhou
# Processing Record 17 of Set 9 | soyo
# Processing Record 18 of Set 9 | luanda
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | kokologo
# Processing Record 21 of Set 9 | te anau
# Processing Record 22 of Set 9 | dhidhdhoo
# Processing Record 23 of Set 9 | yumen
# Processing Record 24 of Set 9 | tomatlan
# Processing Record 25 of Set 9 | lampa
# Processing Record 26 of Set 9 | cotonou
# Processing Record 27 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 9 | zaraza
# Processing Record 29 of Set 9 | kununurra
# Processing Record 30 of Set 9 | anloga
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | ramsgate
# Processing Record 33 of Set 9 | mahibadhoo
# Processing Record 34 of Set 9 | vieste
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | sinnamary
# Processing Record 37 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 9 | concarneau
# Processing Record 39 of Set 9 | edd
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | ko samui
# Processing Record 42 of Set 9 | zhangjiakou
# Processing Record 43 of Set 9 | prince george
# Processing Record 44 of Set 9 | porto walter
# Processing Record 45 of Set 9 | tarabuco
# Processing Record 46 of Set 9 | mareeba
# Processing Record 47 of Set 9 | sosenskiy
# Processing Record 48 of Set 9 | atambua
# Processing Record 49 of Set 9 | tessalit
# Processing Record 50 of Set 9 | asau
# Processing Record 1 of Set 10 | pemangkat
# Processing Record 2 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 10 | ontario
# Processing Record 4 of Set 10 | kirkwall
# Processing Record 5 of Set 10 | muisne
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | wick
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | lewiston
# Processing Record 11 of Set 10 | faya
# Processing Record 12 of Set 10 | chivor
# Processing Record 13 of Set 10 | mancio lima
# Processing Record 14 of Set 10 | severodvinsk
# Processing Record 15 of Set 10 | tura
# Processing Record 16 of Set 10 | atar
# Processing Record 17 of Set 10 | vao
# Processing Record 18 of Set 10 | lebu
# Processing Record 19 of Set 10 | chuy
# Processing Record 20 of Set 10 | anadyr
# Processing Record 21 of Set 10 | burica
# City not found. Skipping...
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | port hawkesbury
# Processing Record 24 of Set 10 | varadero
# Processing Record 25 of Set 10 | am timan
# Processing Record 26 of Set 10 | srednekolymsk
# Processing Record 27 of Set 10 | satara
# Processing Record 28 of Set 10 | agadez
# Processing Record 29 of Set 10 | salinas
# Processing Record 30 of Set 10 | huntsville
# Processing Record 31 of Set 10 | lasa
# Processing Record 32 of Set 10 | asyut
# Processing Record 33 of Set 10 | tromso
# Processing Record 34 of Set 10 | bonthe
# Processing Record 35 of Set 10 | aquino
# Processing Record 36 of Set 10 | matay
# Processing Record 37 of Set 10 | moa
# Processing Record 38 of Set 10 | muslyumovo
# Processing Record 39 of Set 10 | verkhoyansk
# Processing Record 40 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 10 | mikuni
# Processing Record 42 of Set 10 | shetpe
# Processing Record 43 of Set 10 | malakal
# Processing Record 44 of Set 10 | cayenne
# Processing Record 45 of Set 10 | lamar
# Processing Record 46 of Set 10 | rexburg
# Processing Record 47 of Set 10 | yabelo
# Processing Record 48 of Set 10 | melchor de mencos
# Processing Record 49 of Set 10 | la palma
# Processing Record 50 of Set 10 | maneadero
# Processing Record 1 of Set 11 | touros
# Processing Record 2 of Set 11 | tezu
# Processing Record 3 of Set 11 | itarantim
# Processing Record 4 of Set 11 | kimbe
# Processing Record 5 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 6 of Set 11 | gundorovskiy
# Processing Record 7 of Set 11 | safranbolu
# Processing Record 8 of Set 11 | pangnirtung
# Processing Record 9 of Set 11 | eureka
# Processing Record 10 of Set 11 | saint-joseph
# Processing Record 11 of Set 11 | biloxi
# Processing Record 12 of Set 11 | twentynine palms
# Processing Record 13 of Set 11 | acarau
# Processing Record 14 of Set 11 | bor
# Processing Record 15 of Set 11 | kruisfontein
# Processing Record 16 of Set 11 | san andres
# Processing Record 17 of Set 11 | nanchang
# Processing Record 18 of Set 11 | storforshei
# Processing Record 19 of Set 11 | marienburg
# Processing Record 20 of Set 11 | chara
# Processing Record 21 of Set 11 | henties bay
# Processing Record 22 of Set 11 | oum hadjer
# Processing Record 23 of Set 11 | monster
# Processing Record 24 of Set 11 | sabha
# Processing Record 25 of Set 11 | paso de ovejas
# Processing Record 26 of Set 11 | biltine
# Processing Record 27 of Set 11 | romans-sur-isere
# Processing Record 28 of Set 11 | mezen
# Processing Record 29 of Set 11 | chatrapur
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | jumla
# Processing Record 32 of Set 11 | nizwa
# Processing Record 33 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 11 | lappeenranta
# Processing Record 35 of Set 11 | mina
# Processing Record 36 of Set 11 | kieta
# Processing Record 37 of Set 11 | magrath
# Processing Record 38 of Set 11 | qeshm
# Processing Record 39 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 40 of Set 11 | naze
# Processing Record 41 of Set 11 | serenje
# Processing Record 42 of Set 11 | mizdah
# Processing Record 43 of Set 11 | nanortalik
# Processing Record 44 of Set 11 | urucara
# Processing Record 45 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 11 | pitogo
# Processing Record 47 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 11 | cumpas
# Processing Record 49 of Set 11 | ancud
# Processing Record 50 of Set 11 | rio grande
# Processing Record 1 of Set 12 | trairi
# Processing Record 2 of Set 12 | ayan
# Processing Record 3 of Set 12 | port macquarie
# Processing Record 4 of Set 12 | vostok
# Processing Record 5 of Set 12 | tahe
# Processing Record 6 of Set 12 | coffs harbour
# Processing Record 7 of Set 12 | kautokeino
# Processing Record 8 of Set 12 | kadyy
# Processing Record 9 of Set 12 | kotaparh
# Processing Record 10 of Set 12 | kupang
# Processing Record 11 of Set 12 | port keats
# Processing Record 12 of Set 12 | bara
# Processing Record 13 of Set 12 | singaraja
# Processing Record 14 of Set 12 | vanavara
# Processing Record 15 of Set 12 | pimentel
# Processing Record 16 of Set 12 | vestmannaeyjar
# Processing Record 17 of Set 12 | xining
# Processing Record 18 of Set 12 | maridi
# Processing Record 19 of Set 12 | boca do acre
# Processing Record 20 of Set 12 | mantua
# Processing Record 21 of Set 12 | iskateley
# Processing Record 22 of Set 12 | vallenar
# Processing Record 23 of Set 12 | ardakan
# Processing Record 24 of Set 12 | acajutla
# Processing Record 25 of Set 12 | visby
# Processing Record 26 of Set 12 | cambridge
# Processing Record 27 of Set 12 | biritiba-mirim
# Processing Record 28 of Set 12 | katherine
# Processing Record 29 of Set 12 | marawi
# Processing Record 30 of Set 12 | ipameri
# Processing Record 31 of Set 12 | mechanicsville
# Processing Record 32 of Set 12 | nome
# Processing Record 33 of Set 12 | sehithwa
# Processing Record 34 of Set 12 | ternate
# Processing Record 35 of Set 12 | batticaloa
# Processing Record 36 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 37 of Set 12 | merauke
# Processing Record 38 of Set 12 | vardo
# Processing Record 39 of Set 12 | zyryanka
# Processing Record 40 of Set 12 | cassilandia
# Processing Record 41 of Set 12 | zapolyarnyy
# Processing Record 42 of Set 12 | naliya
# Processing Record 43 of Set 12 | menongue
# Processing Record 44 of Set 12 | natal
# Processing Record 45 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 12 | chuguyevka
# Processing Record 47 of Set 12 | jinchang
# Processing Record 48 of Set 12 | kamenka
# Processing Record 49 of Set 12 | svetlyy
# Processing Record 50 of Set 12 | karagay
# Processing Record 1 of Set 13 | ormara
# Processing Record 2 of Set 13 | ca mau
# Processing Record 3 of Set 13 | tanout
# Processing Record 4 of Set 13 | sao felix do xingu
# Processing Record 5 of Set 13 | harlingen
# Processing Record 6 of Set 13 | mehamn
# Processing Record 7 of Set 13 | panama city
# Processing Record 8 of Set 13 | portland
# Processing Record 9 of Set 13 | verkhniy fiagdon
# Processing Record 10 of Set 13 | meulaboh
# Processing Record 11 of Set 13 | mangla
# Processing Record 12 of Set 13 | aleksandrov gay
# Processing Record 13 of Set 13 | kochki
# Processing Record 14 of Set 13 | eskil
# Processing Record 15 of Set 13 | jussara
# Processing Record 16 of Set 13 | tarifa
# Processing Record 17 of Set 13 | port lincoln
# Processing Record 18 of Set 13 | saint-pierre
# Processing Record 19 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 13 | auki
# Processing Record 21 of Set 13 | lapua
# Processing Record 22 of Set 13 | dingzhou
# Processing Record 23 of Set 13 | dibulla
# Processing Record 24 of Set 13 | iracoubo
# Processing Record 25 of Set 13 | sumbuya
# Processing Record 26 of Set 13 | katiola
# Processing Record 27 of Set 13 | hasaki
# Processing Record 28 of Set 13 | kyren
# Processing Record 29 of Set 13 | gawler
# Processing Record 30 of Set 13 | dire
# Processing Record 31 of Set 13 | koumac
# Processing Record 32 of Set 13 | crestview
# Processing Record 33 of Set 13 | cochrane
# Processing Record 34 of Set 13 | saint anthony
# Processing Record 35 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 13 | terney
# Processing Record 37 of Set 13 | erenhot
# Processing Record 38 of Set 13 | solnechnyy
# Processing Record 39 of Set 13 | port hardy
# Processing Record 40 of Set 13 | trabzon
# Processing Record 41 of Set 13 | hafizabad
# Processing Record 42 of Set 13 | sri aman
# Processing Record 43 of Set 13 | kavieng
# Processing Record 44 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 13 | san pedro
# Processing Record 46 of Set 13 | weymouth
# Processing Record 47 of Set 13 | antofagasta
# Processing Record 48 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 13 | hannibal
# Processing Record 50 of Set 13 | gornopravdinsk
# Processing Record 1 of Set 14 | korla
# Processing Record 2 of Set 14 | tumut
# Processing Record 3 of Set 14 | uvira
# Processing Record 4 of Set 14 | sainte-maxime
# Processing Record 5 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 14 | mitsamiouli
# Processing Record 7 of Set 14 | khilchipur
# Processing Record 8 of Set 14 | alofi
# Processing Record 9 of Set 14 | lafia
# Processing Record 10 of Set 14 | cairns
# Processing Record 11 of Set 14 | noumea
# Processing Record 12 of Set 14 | vilyuysk
# Processing Record 13 of Set 14 | stellenbosch
# Processing Record 14 of Set 14 | pitman
# Processing Record 15 of Set 14 | el alto
# Processing Record 16 of Set 14 | grao mogol
# Processing Record 17 of Set 14 | yomou
# Processing Record 18 of Set 14 | craig
# Processing Record 19 of Set 14 | avera
# Processing Record 20 of Set 14 | maldonado
# Processing Record 21 of Set 14 | deputatskiy
# Processing Record 22 of Set 14 | bandarbeyla
# Processing Record 23 of Set 14 | lagoa formosa
# Processing Record 24 of Set 14 | gao
# Processing Record 25 of Set 14 | goundam
# Processing Record 26 of Set 14 | vikhorevka
# Processing Record 27 of Set 14 | gobabis
# Processing Record 28 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 14 | benjamin aceval
# Processing Record 30 of Set 14 | yuzhou
# Processing Record 31 of Set 14 | yuancheng
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | callaway
# Processing Record 34 of Set 14 | catacocha
# Processing Record 35 of Set 14 | port augusta
# Processing Record 36 of Set 14 | sidi ali
# Processing Record 37 of Set 14 | marzuq
# Processing Record 38 of Set 14 | chabahar
# Processing Record 39 of Set 14 | vila velha
# Processing Record 40 of Set 14 | villazon
# Processing Record 41 of Set 14 | labuan
# Processing Record 42 of Set 14 | ola
# Processing Record 43 of Set 14 | danilovka
# Processing Record 44 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 14 | mayna
# Processing Record 47 of Set 14 | innisfail
# Processing Record 48 of Set 14 | mahajanga
# Processing Record 49 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 14 | vaitape
# Processing Record 1 of Set 15 | kumukh
# Processing Record 2 of Set 15 | prieska
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | hovd
# Processing Record 5 of Set 15 | cozumel
# Processing Record 6 of Set 15 | kloulklubed
# Processing Record 7 of Set 15 | morondava
# Processing Record 8 of Set 15 | tazmalt
# Processing Record 9 of Set 15 | jalu
# Processing Record 10 of Set 15 | chapais
# Processing Record 11 of Set 15 | lancaster
# Processing Record 12 of Set 15 | muli
# Processing Record 13 of Set 15 | baghdad
# Processing Record 14 of Set 15 | harper
# Processing Record 15 of Set 15 | maicao
# Processing Record 16 of Set 15 | kokopo
# Processing Record 17 of Set 15 | amapa
# Processing Record 18 of Set 15 | buin
# Processing Record 19 of Set 15 | krasnoselkup
# Processing Record 20 of Set 15 | stornoway
# Processing Record 21 of Set 15 | san lawrenz
# Processing Record 22 of Set 15 | vacaria
# Processing Record 23 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 15 | beruwala
# Processing Record 25 of Set 15 | russell
# Processing Record 26 of Set 15 | nerchinskiy zavod
# Processing Record 27 of Set 15 | ashland
# Processing Record 28 of Set 15 | apastovo
# Processing Record 29 of Set 15 | hambantota
# Processing Record 30 of Set 15 | havoysund
# Processing Record 31 of Set 15 | mecca
# Processing Record 32 of Set 15 | bardiyah
# Processing Record 33 of Set 15 | kidal
# Processing Record 34 of Set 15 | saint-augustin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Jutai  -5.1833  -68.9000     98.71        34          26
# 1  Arraial Do Cabo -22.9661  -42.0278     75.06        69         100
# 2            Vaini -21.2000 -175.2000     75.36        94          40
# 3       Bredasdorp -34.5322   20.0403     56.14        72          15
# 4       Nikolskoye  59.7035   30.7861     48.09        93          95
# 5           Barrow  71.2906 -156.7887     33.82        86         100
# 6     Ponta Do Sol  32.6667  -17.1000     76.01        85          92
# 7           Hobart -42.8794  147.3294     49.86        80         100
# 8           Marand  38.4329   45.7749     69.53        18           1
# 9        Las Vegas  36.1750 -115.1372     85.60        27           0
#
#    Wind Speed Country Current Description
# 0        3.56      BR    scattered clouds
# 1       12.66      BR     overcast clouds
# 2        4.61      TO    scattered clouds
# 3        7.83      ZA          few clouds
# 4        4.61      RU     overcast clouds
# 5       12.66      US     overcast clouds
# 6        1.30      PT     overcast clouds
# 7        4.61      AU     overcast clouds
# 8        5.50      IR           clear sky
# 9        3.44      US           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_new_columns]

# Display sample data
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Jutai      BR  -5.1833  -68.9000     98.71        34
# 1    Arraial Do Cabo      BR -22.9661  -42.0278     75.06        69
# 2              Vaini      TO -21.2000 -175.2000     75.36        94
# 3         Bredasdorp      ZA -34.5322   20.0403     56.14        72
# 4         Nikolskoye      RU  59.7035   30.7861     48.09        93
# ..               ...     ...      ...       ...       ...       ...
# 672        Havoysund      NO  70.9963   24.6622     46.63        91
# 673            Mecca      SA  21.4267   39.8261     88.20        36
# 674         Bardiyah      LY  31.7561   25.0865     73.44        59
# 675            Kidal      ML  18.4411    1.4078    101.82        10
# 676   Saint-Augustin      CA  51.2260  -58.6502     62.67        40
#
#      Cloudiness  Wind Speed Current Description
# 0            26        3.56    scattered clouds
# 1           100       12.66     overcast clouds
# 2            40        4.61    scattered clouds
# 3            15        7.83          few clouds
# 4            95        4.61     overcast clouds
# ..          ...         ...                 ...
# 672         100       17.94     overcast clouds
# 673           1        5.41           clear sky
# 674           1       10.11           clear sky
# 675          15       13.31          few clouds
# 676          28        8.68    scattered clouds
#
# [677 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
WeatherPy_Database = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(WeatherPy_Database, index_label="WeatherPy_Database")
